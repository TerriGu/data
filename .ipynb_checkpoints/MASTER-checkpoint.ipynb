# %%
import pandas as pd

# %%
#import and read data
dataFile="https://github.com/TerriGu/data/raw/master/index2017.xlsx"
index2017=pd.read_excel(dataFile)
index2017.head()
# Out:
#    CountryID                       Country Name                      Region  \
# 0         93                            Lebanon  Middle East / North Africa
# 1        183                           Zimbabwe          Sub-Saharan Africa
# 2        139  Saint. Vincent and the Grenadines                    Americas
# 3          1                        Afghanistan                Asia-Pacific
# 4         43                             Cyprus                      Europe
#
#    World Rank  Region Rank  2017 Score  Property Rights  \
# 0         137           11        53.3             43.8
# 1         175           45        44.0             27.3
# 2          59            9        65.2             37.3
# 3         163           40        48.9             12.6
# 4          48           24        67.9             75.4
#
#    Judical Effectiveness  Government Integrity  Tax Burden  \
# 0                   25.3                  23.3        91.8
# 1                   26.1                  14.7        61.1
# 2                   68.8                  47.6        72.8
# 3                   28.4                  27.5        91.6
# 4                   60.7                  53.6        73.0
#
#             ...             Tax Burden perc of GDP  \
# 0           ...                               13.8
# 1           ...                               24.8
# 2           ...                               23.9
# 3           ...                                6.5
# 4           ...                               36.3
#
#    Gov't Expenditure perc of GDP   Population_Millions   GDP Billions PPP   \
# 0                            28.5                  4.6                83.1
# 1                            28.5                 13.4                28.1
# 2                            28.7                  0.1                 1.2
# 3                            27.1                 32.0                62.3
# 4                            41.2                  0.9                28.1
#
#    GDP Growth Rate  GDP per Capita PPP  Unemployment  Inflation Perc  \
# 0              1.0             18240.0           7.1            -3.7
# 1              1.5              2096.0           9.3            -2.4
# 2              1.6             10956.0          20.0            -1.7
# 3              1.5              1947.0           9.6            -1.5
# 4              1.6             32786.0          15.6            -1.5
#
#    FDI Inflow Millions  Public Debt Perc of GDP
# 0               2341.0                    139.1
# 1                421.0                     53.0
# 2                120.7                     73.6
# 3                 58.0                      6.8
# 4               4534.1                    108.7
#
# [5 rows x 31 columns]

# %%
#determine datatype and clear missing data
index2017.dtypes
index_2017=pd.read_excel(dataFile,na_values='')
index_2017.dtypes
# Out:
# CountryID                           int64
# Country Name                       object
# Region                             object
# World Rank                          int64
# Region Rank                         int64
# 2017 Score                        float64
# Property Rights                   float64
# Judical Effectiveness             float64
# Government Integrity              float64
# Tax Burden                        float64
# Gov't Spending                    float64
# Fiscal Health                     float64
# Business Freedom                  float64
# Labor Freedom                     float64
# Monetary Freedom                  float64
# Trade Freedom                     float64
# Investment Freedom                  int64
# Financial Freedom                   int64
# Tariff Rate                       float64
# Income Tax Rate                   float64
# Corporate Tax Rate                float64
# Tax Burden perc of GDP            float64
# Gov't Expenditure perc of GDP     float64
# Population_Millions               float64
#  GDP Billions PPP                 float64
# GDP Growth Rate                   float64
# GDP per Capita PPP                float64
# Unemployment                      float64
# Inflation Perc                    float64
# FDI Inflow Millions               float64
# Public Debt Perc of GDP           float64
# dtype: object

# %%
# packages needed to plot the variables
from scipy.stats import norm
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# explore the first variable: GDP Growth Rate
index_2017["GDP Growth Rate"].describe()
# Out:
# count    179.000000
# mean       2.555307
# std        3.858263
# min      -21.500000
# 25%        1.350000
# 50%        3.000000
# 75%        4.300000
# max       10.200000
# Name: GDP Growth Rate, dtype: float64

# %%
index_2017["GDP Growth Rate"].std()/index_2017["GDP Growth Rate"].mean()
# Out:
# 1.5099017967144996

# %%
index_2017["GDP Growth Rate"].skew()
# Out:
# -3.000817784731934

# %%
index_2017["GDP Growth Rate"].kurt()
# Out:
# 15.555836893646962

# %%
# plot the variable "GDP Growth Rate" in histogram and box
meanGDP=index_2017['GDP Growth Rate'].mean()
mdGDP=index_2017['GDP Growth Rate'].median()

sns.distplot(index_2017['GDP Growth Rate'].dropna())
plt.title('GDP Growth Rate 2017')
plt.axvline(meanGDP, color='b', linestyle='dashed', linewidth=1,label='mean')
plt.axvline(mdGDP, color='r', linestyle='dashed', linewidth=1,label='median')
plt.show()

# %%
plot,dataIndex=index_2017['GDP Growth Rate'].plot.box(vert=False,return_type='both')
plt.show()

# %%
[value.get_xdata() for value in dataIndex["boxes"]]
# Out:
# [array([1.35, 1.35, 4.3 , 4.3 , 1.35])]

# %%
[value.get_xdata() for value in dataIndex["caps"]]
# Out:
# [array([-1.8, -1.8]), array([8.6, 8.6])]

# %%
#explore the second variable: Inflation percentage
index_2017["Inflation Perc"].describe()
# Out:
# count    179.000000
# mean       4.120670
# std       10.415706
# min       -3.700000
# 25%        0.100000
# 50%        1.900000
# 75%        5.150000
# max      121.700000
# Name: Inflation Perc, dtype: float64

# %%
index_2017["Inflation Perc"].std()/index_2017["Inflation Perc"].mean()
# Out:
# 2.5276726685317903

# %%
index_2017["Inflation Perc"].skew()
# Out:
# 8.71842025902743

# %%
index_2017["Inflation Perc"].kurt()
# Out:
# 93.49635089140416

# %%
# plot the variable "Inflacton Percentage" in histogram and box
meanInf=index_2017['Inflation Perc'].mean()
mdInf=index_2017['Inflation Perc'].median()

sns.distplot(index_2017['Inflation Perc'].dropna())
plt.title('Inflation Percentage 2017')
plt.axvline(meanInf, color='b', linestyle='dashed', linewidth=1,label='mean')
plt.axvline(mdInf, color='r', linestyle='dashed', linewidth=1,label='median')
plt.show()

# %%
plot,dataIndex=index_2017['Inflation Perc'].plot.box(vert=False,return_type='both')
plt.show()

# %%
[value.get_xdata() for value in dataIndex["boxes"]]
# Out:
# [array([0.1 , 0.1 , 5.15, 5.15, 0.1 ])]

# %%
[value.get_xdata() for value in dataIndex["caps"]]
# Out:
# [array([-3.7, -3.7]), array([12., 12.])]

# %%
#explore the third variable: Financial Freedom
index_2017["Financial Freedom"].describe()
# Out:
# count    179.000000
# mean      48.435754
# std       19.103799
# min        0.000000
# 25%       30.000000
# 50%       50.000000
# 75%       60.000000
# max       90.000000
# Name: Financial Freedom, dtype: float64

# %%
index_2017["Financial Freedom"].std()/index_2017["Financial Freedom"].mean()
# Out:
# 0.3944152179971563

# %%
index_2017["Financial Freedom"].skew()
# Out:
# -0.08186839894280974

# %%
index_2017["Financial Freedom"].kurt()
# Out:
# -0.5368056710232287

# %%
# plot the variable "Financial Freedom" in histogram and box
meanfr=index_2017['Financial Freedom'].mean()
mdfr=index_2017['Financial Freedom'].median()

sns.distplot(index_2017['Financial Freedom'].dropna())
plt.title('Financial Freedom 2017')
plt.axvline(meanfr, color='b', linestyle='dashed', linewidth=1,label='mean')
plt.axvline(mdfr, color='r', linestyle='dashed', linewidth=1,label='median')
plt.show()

# %%
plot,dataIndex=index_2017['Financial Freedom'].plot.box(vert=False,return_type='both')
plt.show()

# %%
[value.get_xdata() for value in dataIndex["boxes"]]
# Out:
# [array([30., 30., 60., 60., 30.])]

# %%
[value.get_xdata() for value in dataIndex["caps"]]
# Out:
# [array([0., 0.]), array([90., 90.])]

# %%
# check out the correlation among the three variables and plot it
columns=['GDP Growth Rate', 'Inflation Perc','Financial Freedom']
indexin2017=pd.DataFrame(index_2017,columns=columns)

# %%
pd.plotting.scatter_matrix(indexin2017,figsize=(10,10))
plt.show()

# %%
indexin2017.corr()
# Out:
#                    GDP Growth Rate  Inflation Perc  Financial Freedom
# GDP Growth Rate           1.000000       -0.246876           0.008955
# Inflation Perc           -0.246876        1.000000          -0.285988
# Financial Freedom         0.008955       -0.285988           1.000000

# %%
# the spearman method
indexin2017.corr(method='spearman')
# Out:
#                    GDP Growth Rate  Inflation Perc  Financial Freedom
# GDP Growth Rate           1.000000        0.070959          -0.104427
# Inflation Perc            0.070959        1.000000          -0.380638
# Financial Freedom        -0.104427       -0.380638           1.000000

# %%
# load package needed for map visualization
import geopandas as gpd

# %%
# import and read map file
Map='https://github.com/TerriGu/data/raw/master/ne_110m_admin_0_countries.zip'

# %%
WorldMap = gpd.GeoDataFrame.from_file(Map)

# %%
WorldMap.head()
# Out:
#    scalerank       featurecla  LABELRANK            SOVEREIGNT SOV_A3  \
# 0          1  Admin-0 country        3.0           Afghanistan    AFG
# 1          1  Admin-0 country        3.0                Angola    AGO
# 2          1  Admin-0 country        6.0               Albania    ALB
# 3          1  Admin-0 country        4.0  United Arab Emirates    ARE
# 4          1  Admin-0 country        2.0             Argentina    ARG
#
#    ADM0_DIF  LEVEL               TYPE                 ADMIN ADM0_A3  \
# 0       0.0    2.0  Sovereign country           Afghanistan     AFG
# 1       0.0    2.0  Sovereign country                Angola     AGO
# 2       0.0    2.0  Sovereign country               Albania     ALB
# 3       0.0    2.0  Sovereign country  United Arab Emirates     ARE
# 4       0.0    2.0  Sovereign country             Argentina     ARG
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                     REGION_WB NAME_LEN LONG_LEN  ABBREV_LEN  TINY HOMEPART  \
# 0                  South Asia     11.0     11.0         4.0 -99.0      1.0
# 1          Sub-Saharan Africa      6.0      6.0         4.0 -99.0      1.0
# 2       Europe & Central Asia      7.0      7.0         4.0 -99.0      1.0
# 3  Middle East & North Africa     20.0     20.0         6.0 -99.0      1.0
# 4   Latin America & Caribbean      9.0      9.0         4.0 -99.0      1.0
#
#    MIN_ZOOM MIN_LABEL MAX_LABEL  \
# 0       0.0       3.0       7.0
# 1       0.0       3.0       7.0
# 2       0.0       5.0      10.0
# 3       0.0       4.0       9.0
# 4       0.0       2.0       7.0
#
#                                             geometry
# 0  POLYGON ((61.21081709172574 35.65007233330923,...
# 1  (POLYGON ((23.90415368011818 -11.7222815894063...
# 2  POLYGON ((21.0200403174764 40.84272695572588, ...
# 3  POLYGON ((51.57951867046327 24.24549713795111,...
# 4  (POLYGON ((-66.95992000000001 -54.896810000000...
#
# [5 rows x 72 columns]

# %%
WorldMap.dtypes
# Out:
# scalerank       int64
# featurecla     object
# LABELRANK     float64
# SOVEREIGNT     object
# SOV_A3         object
# ADM0_DIF      float64
# LEVEL         float64
# TYPE           object
# ADMIN          object
# ADM0_A3        object
# GEOU_DIF      float64
# GEOUNIT        object
# GU_A3          object
# SU_DIF        float64
# SUBUNIT        object
# SU_A3          object
# BRK_DIFF      float64
# NAME           object
# NAME_LONG      object
# BRK_A3         object
# BRK_NAME       object
# BRK_GROUP      object
# ABBREV         object
# POSTAL         object
# FORMAL_EN      object
# FORMAL_FR      object
# NAME_CIAWF     object
# NOTE_ADM0      object
# NOTE_BRK       object
# NAME_SORT      object
#                ...
# INCOME_GRP     object
# WIKIPEDIA     float64
# FIPS_10_       object
# ISO_A2         object
# ISO_A3         object
# ISO_A3_EH      object
# ISO_N3         object
# UN_A3          object
# WB_A2          object
# WB_A3          object
# WOE_ID        float64
# WOE_ID_EH     float64
# WOE_NOTE       object
# ADM0_A3_IS     object
# ADM0_A3_US     object
# ADM0_A3_UN    float64
# ADM0_A3_WB    float64
# CONTINENT      object
# REGION_UN      object
# SUBREGION      object
# REGION_WB      object
# NAME_LEN      float64
# LONG_LEN      float64
# ABBREV_LEN    float64
# TINY          float64
# HOMEPART      float64
# MIN_ZOOM      float64
# MIN_LABEL     float64
# MAX_LABEL     float64
# geometry       object
# Length: 72, dtype: object

# %%
# the variable used for merging will be "country," so check it out in the map file first (the name is SOVEREIGNT)
WorldMap['SOVEREIGNT']
# Out:
# 0                      Afghanistan
# 1                           Angola
# 2                          Albania
# 3             United Arab Emirates
# 4                        Argentina
# 5                          Armenia
# 6                       Antarctica
# 7                           France
# 8                        Australia
# 9                          Austria
# 10                      Azerbaijan
# 11                         Burundi
# 12                         Belgium
# 13                           Benin
# 14                    Burkina Faso
# 15                      Bangladesh
# 16                        Bulgaria
# 17                     The Bahamas
# 18          Bosnia and Herzegovina
# 19                         Belarus
# 20                          Belize
# 21                         Bolivia
# 22                          Brazil
# 23                          Brunei
# 24                          Bhutan
# 25                        Botswana
# 26        Central African Republic
# 27                          Canada
# 28                     Switzerland
# 29                           Chile
#                   ...
# 147             Republic of Serbia
# 148                       Suriname
# 149                       Slovakia
# 150                       Slovenia
# 151                         Sweden
# 152                      Swaziland
# 153                          Syria
# 154                           Chad
# 155                           Togo
# 156                       Thailand
# 157                     Tajikistan
# 158                   Turkmenistan
# 159                     East Timor
# 160            Trinidad and Tobago
# 161                        Tunisia
# 162                         Turkey
# 163                         Taiwan
# 164    United Republic of Tanzania
# 165                         Uganda
# 166                        Ukraine
# 167                        Uruguay
# 168       United States of America
# 169                     Uzbekistan
# 170                      Venezuela
# 171                        Vietnam
# 172                        Vanuatu
# 173                          Yemen
# 174                   South Africa
# 175                         Zambia
# 176                       Zimbabwe
# Name: SOVEREIGNT, Length: 177, dtype: object

# %%
# then check it out in the data file (the name is Country Name)
index_2017['Country Name']
# Out:
# 0                                Lebanon
# 1                               Zimbabwe
# 2      Saint. Vincent and the Grenadines
# 3                            Afghanistan
# 4                                 Cyprus
# 5                                 Greece
# 6                            Switzerland
# 7                               Bulgaria
# 8                             Micronesia
# 9                 Bosnia and Herzegovina
# 10                                Jordan
# 11                              Thailand
# 12                                Poland
# 13                              Dominica
# 14                          Saint. Lucia
# 15                             Lithuania
# 16                           El Salvador
# 17                                Belize
# 18                                Israel
# 19                               Romania
# 20                               Croatia
# 21                             Singapore
# 22                              Slovenia
# 23                                 Spain
# 24                                Kosovo
# 25                     Brunei Darussalam
# 26                       Solomon Islands
# 27                               Taiwan
# 28                                Guyana
# 29                       Slovak Republic
#                      ...
# 149                               Gambia
# 150                             Suriname
# 151                                Nepal
# 152                               Bhutan
# 153                           Madagascar
# 154                                Haiti
# 155                              Liberia
# 156                               Turkey
# 157                               Guinea
# 158                           Uzbekistan
# 159                              Uruguay
# 160                         Sierra Leone
# 161                               Brazil
# 162                              Nigeria
# 163                              Eritrea
# 164                              Moldova
# 165                               Zambia
# 166                             Ethiopia
# 167                               Angola
# 168                                Egypt
# 169                                Burma
# 170                                 Iran
# 171                              Belarus
# 172                               Russia
# 173                                Sudan
# 174                                Ghana
# 175                               Malawi
# 176                            Argentina
# 177                              Ukraine
# 178                            Venezuela
# Name: Country Name, Length: 179, dtype: object

# %%
#merge!!!
WM=WorldMap.merge(index_2017, left_on='SOVEREIGNT', right_on='Country Name')

# %%
#before merge, how many rows do I have?
WorldMap.shape[0]
# Out:
# 177

# %%
#after merge, how many rows do I have?
WM.shape[0]
#and I know I'll be missing 26 countries (177-151)
# Out:
# 151

# %%
#plot to see what countries/areas I'm missing
# %matplotlib inline
base = WorldMap.plot(color='gray',figsize=(20,13))

WM.plot(ax=base, color='pink')

# %%
# plot the first variable "GDP growth rate" in map
WM['GDP Growth Rate'].describe()
# Out:
# count    151.000000
# mean       2.586093
# std        3.555541
# min      -21.500000
# 25%        1.250000
# 50%        3.000000
# 75%        4.250000
# max       10.200000
# Name: GDP Growth Rate, dtype: float64

# %%
import matplotlib.pyplot as plt

base = WorldMap.plot(color='gray',figsize=(20,13))

topLayer=WM.plot(ax=base,column='GDP Growth Rate',cmap='YlGnBu',scheme='Quantiles',k=5,legend=True,
                  legend_kwds={'loc': 3,'title':'GDP Growth Rate: \n (gray missing)'})
topLayer.set_title('2017 Country GDP Growth Rate', 
                   color='black',fontdict={'fontsize':30})
leg = topLayer.get_legend()
plt.setp(leg.get_title(), multialignment='center')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\Anaconda3\envs\StupidMap\lib\site-packages\geopandas\plotting.py in __pysal_choro(values, scheme, k)
#     511     try:
# --> 512         from pysal.esda.mapclassify import (
#     513             Quantiles, Equal_Interval, Fisher_Jenks)
#
# ~\Anaconda3\envs\StupidMap\lib\site-packages\pysal\__init__.py in <module>()
#      94 from pysal.core.util.weight_converter import weight_convert
# ---> 95 import pysal.spreg
#      96 import pysal.examples
#
# ~\Anaconda3\envs\StupidMap\lib\site-packages\pysal\spreg\__init__.py in <module>()
# ----> 1 from .ols import *
#       2 from .diagnostics import *
#       3 from .diagnostics_sp import *
#
# ~\Anaconda3\envs\StupidMap\lib\site-packages\pysal\spreg\ols.py in <module>()
#       7 from . import user_output as USER
# ----> 8 from . import summary_output as SUMMARY
#       9 from . import robust as ROBUST
#
# ~\Anaconda3\envs\StupidMap\lib\site-packages\pysal\spreg\summary_output.py in <module>()
#       9 from . import diagnostics_tsls as diagnostics_tsls
# ---> 10 from . import diagnostics_sp as diagnostics_sp
#      11 import pysal
#
# ~\Anaconda3\envs\StupidMap\lib\site-packages\pysal\spreg\diagnostics_sp.py in <module>()
#       6 from .utils import spdot
# ----> 7 from scipy.stats.stats import chisqprob
#       8 from scipy.stats import norm
#
# ImportError: cannot import name 'chisqprob'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-47-e07f209f067a> in <module>()
#       4
#       5 topLayer=WM.plot(ax=base,column='GDP Growth Rate',cmap='YlGnBu',scheme='Quantiles',k=5,legend=True,
# ----> 6                   legend_kwds={'loc': 3,'title':'GDP Growth Rate: \n (gray missing)'})
#       7 topLayer.set_title('2017 Country GDP Growth Rate',
#       8                    color='black',fontdict={'fontsize':30})
#
# ~\Anaconda3\envs\StupidMap\lib\site-packages\geopandas\geodataframe.py in plot(self, *args, **kwargs)
#     524         from there.
#     525         """
# --> 526         return plot_dataframe(self, *args, **kwargs)
#     527
#     528     plot.__doc__ = plot_dataframe.__doc__
#
# ~\Anaconda3\envs\StupidMap\lib\site-packages\geopandas\plotting.py in plot_dataframe(df, column, cmap, color, ax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, **style_kwds)
#     422         values = df[column]
#     423     if scheme is not None:
# --> 424         binning = __pysal_choro(values, scheme, k=k)
#     425         # set categorical to True for creating the legend
#     426         categorical = True
#
# ~\Anaconda3\envs\StupidMap\lib\site-packages\geopandas\plotting.py in __pysal_choro(values, scheme, k)
#     523         return binning
#     524     except ImportError:
# --> 525         raise ImportError("PySAL is required to use the 'scheme' keyword")
#
# ImportError: PySAL is required to use the 'scheme' keyword

# %%
# plot the second variable "Financial Freedom" in map
WM['Financial Freedom'].describe(include='all')

# %%
base = WorldMap.plot(color='gray',figsize=(20,13))

topLayer=WM.plot(ax=base,column='Financial Freedom',cmap='YlOrRd',scheme='Quantiles',k=5,legend=True,
                  legend_kwds={'loc': 3,'title':'Financial Freedom (score) : \n (gray missing)'})
topLayer.set_title('2017 Country Financial Freedom', 
                   color='black',fontdict={'fontsize':30})
leg = topLayer.get_legend()
plt.setp(leg.get_title(), multialignment='center')
plt.show()

# %%
# plot the third variable "Inflaction Percentage" in map
WM['Inflation Perc'].describe(include='all')
# Out:
# count    151.000000
# mean       4.491391
# std       11.243528
# min       -3.700000
# 25%        0.100000
# 50%        2.200000
# 75%        5.550000
# max      121.700000
# Name: Inflation Perc, dtype: float64

# %%
base = WorldMap.plot(color='gray',figsize=(20,13))

topLayer=WM.plot(ax=base,column='Inflation Perc',cmap='RdPu',scheme='Quantiles',k=5,legend=True,
                  legend_kwds={'loc': 3,'title':'Inflation Percentage : \n (gray missing)'})
topLayer.set_title('2017 Country Inflation Percentage', 
                   color='black',fontdict={'fontsize':30})
leg = topLayer.get_legend()
plt.setp(leg.get_title(), multialignment='center')
plt.show()
